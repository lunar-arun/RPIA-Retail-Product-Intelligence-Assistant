# %% [markdown]
# ### Exploratory notebook: sentiment tagging
#
# This mirrors `src.nlp.sentiment_analyzer.tag_sentiment` -- a local, lexicon-based
# scorer with no external model download. See that module's docstring for why.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()))

import pandas as pd
from src.config import CLEAN_REVIEWS_PATH
from src.nlp.sentiment_analyzer import tag_sentiment

df = pd.read_csv(CLEAN_REVIEWS_PATH)
tagged = tag_sentiment(df)
tagged[['review_text', 'star_rating', 'sentiment', 'sentiment_score']].head(10)

# %%
tagged['sentiment'].value_counts()
