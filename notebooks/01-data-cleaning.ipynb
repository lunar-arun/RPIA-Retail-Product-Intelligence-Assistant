# %% [markdown]
# ### Exploratory notebook: data cleaning
#
# This mirrors the cleaning logic in `scripts/build_pipeline.py::clean_reviews`.
# For the actual pipeline run, use the script (`python scripts/build_pipeline.py`) -- this notebook is for exploration only.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()))

import pandas as pd
from src.config import RAW_REVIEWS_PATH
from scripts.build_pipeline import clean_reviews

df = pd.read_csv(RAW_REVIEWS_PATH)
print(df.shape)
df.head()

# %% [markdown]
# If `RAW_REVIEWS_PATH` doesn't exist yet, generate it first:
# ```bash
# python scripts/generate_sample_data.py
# ```

# %%
clean_df = clean_reviews(df)
clean_df.describe(include='all')
